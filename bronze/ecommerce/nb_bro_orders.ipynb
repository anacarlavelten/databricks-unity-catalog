# %% [markdown]
# # Notebook para ler e escrever a a tabela orders

# %%
df = spark.read.format("csv").option("head", "true").option("inferschema", "true").load("/Volumes/workspace/raw/volume/Ecommerce/olist_orders_dataset.csv")

# %%
df.write.format("delta").mode("overwrite").saveAsTable("workspace.bronze.tb_orders")
