# %% [markdown]
# # Notebook para ler e escrever a tabela sellers

# %%
df = spark.read.format("csv").option("header", "true").option("inferschema", "true").load("/Volumes/workspace/raw/volume/Ecommerce/olist_sellers_dataset.csv")

# %%
df.write.format("delta").mode("overwrite").saveAsTable("workspace.bronze.db_sellers")
