# %% [markdown]
# # Notebook para ler e escrever a tabela products

# %%
df = spark.read.format("csv").option("head", "true").option("inferschema", "true").load("/Volumes/workspace/raw/volume/Ecommerce/olist_products_dataset.csv")

# %%
df.write.format("delta").mode("overwrite").saveAsTable("workspace.bronze.db_products")
